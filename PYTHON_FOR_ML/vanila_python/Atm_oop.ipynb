# %%
class Atm:
    def __init__(self):
        self.pin = ""
        self.balance = 0
        
        self.menu()
        
    def menu(self):
        user_input = input('''
                        Hello, How would you like to proceed?
                        1. Enter 1 to create pin
                        2. Enter 2 to deposite
                        3. Enter 3 to withdraw
                        4. Enter 4 to check balance
                        5. Enter 5 to exit
        ''')
        if user_input == "1":
            self.create_pin()
        elif user_input == "2":
            self.deposite()
        elif user_input == "3":
            self.withdraw()
        elif user_input == "4":
            self.balance_check()
        else:
            print("bye...")
     
    def create_pin(self):
        self.pin = input("Enter your pin :")
        print("pin set successfully...")
        self.menu()
        
     
    def deposite(self):
        temp = input("Enter your pin :")
        if temp == self.pin:
            amount = int(input("Enter you Deposite amount :"))
            self.balance += amount
            print("Deposited Successfully...!")
        else:
            print("Invalid pin...!")
        self.menu()
            
        
       
    def withdraw(self):
        temp = input("Enter your pin :")
        if temp == self.pin:
            amount = int(input("Enter you Desire amount :"))
            if self.balance >= amount:
                self.balance -= amount
                print("Operational Successfully...!")
        else:
            print("Invalid pin...!")
        self.menu()
        
        
    def balance_check(self):
        temp = input("Enter your pin :")
        if temp == self.pin:
            print(self.balance)
        else:
            print("Invalid pin...!")
        self.menu()
        
sbi = Atm()
# Out:
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         1
# Enter your pin :12345
# pin set successfully...
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         2
# Enter your pin :123456
# Invalid pin...!
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         2
# Enter your pin :12345
# Enter you Deposite amount :500
# Deposited Successfully...!
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         4
# Enter your pin :12345
# 500
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         3
# Enter your pin :300
# Invalid pin...!
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         3
# Enter your pin :12345
# Enter you Desire amount :3000
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         4
# Enter your pin :12345
# 500
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         3
# Enter your pin :12345
# Enter you Desire amount :300
# Operational Successfully...!
#
#                         Hello, How would you like to proceed?
#                         1. Enter 1 to create pin
#                         2. Enter 2 to deposite
#                         3. Enter 3 to withdraw
#                         4. Enter 4 to check balance
#                         5. Enter 5 to exit
#         4
# Enter your pin :12345
# 200
